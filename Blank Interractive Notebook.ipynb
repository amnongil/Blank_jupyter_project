# %% [markdown]
# <center><h1> Blank Interractive Notebook </h1> </center>
#
# #### A demonstration and exploration by Noam Kaplan.
# - Email:    Noam.Kaplan85@gmail.com
# - Linkedin: https://il.linkedin.com/in/noam-kaplan-22b46683

# %%
from IPython.display import Image
Image(filename='pictures/question-mark.jpg', height=250, width=250)

# %%
from helper_functions import *
# Make cells wider
display(HTML("<style>.container { width:80% !important; }</style>"))
# %autosave 60
# Reload models to notebook without restarting kernel
# Use once when starting notebook
# %load_ext autoreload 
# Use to reload externel modules after changes
# %autoreload 2
# Out:
# <style>.container { width:80% !important; }</style>
# Autosaving every 60 seconds

# %% [markdown]
# <a id="top"></a>
# ### <a> Table of contents: </a>
#
# - [Introduction: ](#Intro)
# - [TODO: ](#TODO:)
# - [1. First Chapter](#1.)
#     - [1.1. sub1 ](#1.1.)
#     - [1.2. sub2](#1.2.)
# - [2. Second Chapter](#2.)
#     - [2.1. sub1](#2.1.)
#     - [2.2. sub2](#2.2.)
# - [Appendix](#Appendix)

# %% [markdown]
# <a id='Intro'></a>
# ## <a> Introduction: <a>

# %% [markdown]
# - After pushing to github, notebooks can be viewed with http://nbviewer.jupyter.org/ .
# - You can see this notebook using nbviewer here: http://nbviewer.jupyter.org/github/kaplann/Blank_jupyter_project/blob/master/Blank_proj.ipynb#TODO:

# %% [markdown]
# <a id='#TODO'></a>
# ## <a>  TODO: </a>
# [back to top](#top)

# %% [markdown]
# 1. Add things to do
# 1. Numbering happens on it's own
# 1. Emphasis, aka italics, with *asterisks* or _underscores_.
# 1. Strong emphasis, aka bold, with **asterisks** or __underscores__.
# 1. Strikethrough uses two tildes. ~~Scratch this.~~
# 1. Find these and more [here.](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet "Markdown-Cheatsheet")

# %%
new_section(content_id='1.', title='1. First Chapter ')
# Out:
# <a id="1."></a>
# <div style="text-align:center;background:#661111;padding:40px;color:#ffffff;font-size:2.5em;">1. First Chapter </div>
# [back to top](#top)

# %% [markdown]
# <a id='1.1.'></a>
# ### 1.1.
# [back to top](#top)]

# %% [markdown]
# <a id='1.2.'></a>
# ### 1.2.
# [[back to top](#top)]

# %%
new_section(content_id='2.', title='2. Second Chapter ')
# Out:
# <a id="2."></a>
# <div style="text-align:center;background:#661111;padding:40px;color:#ffffff;font-size:2.5em;">2. Second Chapter </div>
# [back to top](#top)

# %% [markdown]
# <a id='2.1.'></a>
# ### 2.1.
# [[back to top](#top)]

# %% [markdown]
# <a id='2.2.'></a>
# ### 2.2.
# [[back to top](#top)]

# %% [markdown]
# <a id='Appendix'></a>
# ## Appendix
# [[back to top](#top)]

# %% [markdown]
# - Great tutorials:
#  - 1)
#  - 2)
# - Refferences:
#  - 1)
# - Resources:
#  -
#  -

# %% [markdown]
# [[back to top](#top)]
